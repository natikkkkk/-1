# %%
import json
import requests
import urllib.parse
base_url = 'https://itunes.apple.com/search'

artist = 'Miyagi'

params = {
    'term': artist,
    'limit': 200 ,
    'media': 'music',
    'entity': 'song',
    'attribute': 'artistTerm'
}

response = requests.get(f"{base_url}?{urllib.parse.urlencode(params)}")

data = json.loads(response.text)
data = data['results']

# %%
# Все доступные ключи объекта
print(list(data[0].keys()))
# Out:
# ['wrapperType', 'kind', 'artistId', 'collectionId', 'trackId', 'artistName', 'collectionName', 'trackName', 'collectionCensoredName', 'trackCensoredName', 'artistViewUrl', 'collectionViewUrl', 'trackViewUrl', 'previewUrl', 'artworkUrl30', 'artworkUrl60', 'artworkUrl100', 'collectionPrice', 'trackPrice', 'releaseDate', 'collectionExplicitness', 'trackExplicitness', 'discCount', 'discNumber', 'trackCount', 'trackNumber', 'trackTimeMillis', 'country', 'currency', 'primaryGenreName', 'isStreamable']

# %%
import dateutil.parser

# Преобразование строки с датой в объект даты
# **x - скопировать все поля из объекта x
data = map(lambda x: {**x, 'releaseDate': dateutil.parser.isoparse(x['releaseDate'])}, data)

# Убираем лишние поля
data = map(lambda x: {
    'artistId': x['artistId'],
    'collectionId': x['collectionId'],
    'trackId': x['trackId'],
    'artistName': x['artistName'],
    'collectionName': x['collectionCensoredName'],
    'trackName': x['trackCensoredName'],
    'collectionPrice': x['collectionPrice'],
    'trackPrice': x['trackPrice'],
    'releaseDate': x['releaseDate'],
    'collectionExplicitness': x['collectionExplicitness'],
    'trackExplicitness': x['trackExplicitness'],
    'discCount': x['discCount'],
    'discNumber': x['discNumber'],
    'trackCount': x['trackCount'],
    'trackNumber': x['trackNumber'],
    'trackTimeMillis': x['trackTimeMillis'],
    'country': x['country'],
    'currency': x['currency'],
    'primaryGenreName': x['primaryGenreName'],
    'isStreamable': x['isStreamable']
}, data)
data = list(data)
print(list(data[0].keys()))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [9], line 30
#       7 # Убираем лишние поля
#       8 data = map(lambda x: {
#       9     'artistId': x['artistId'],
#      10     'collectionId': x['collectionId'],
#    (...)
#      28     'isStreamable': x['isStreamable']
#      29 }, data)
# ---> 30 data = list(data)
#      31 print(list(data[0].keys()))
#
# Cell In [9], line 15, in <lambda>(x)
#       5 data = map(lambda x: {**x, 'releaseDate': dateutil.parser.isoparse(x['releaseDate'])}, data)
#       7 # Убираем лишние поля
#       8 data = map(lambda x: {
#       9     'artistId': x['artistId'],
#      10     'collectionId': x['collectionId'],
#      11     'trackId': x['trackId'],
#      12     'artistName': x['artistName'],
#      13     'collectionName': x['collectionCensoredName'],
#      14     'trackName': x['trackCensoredName'],
# ---> 15     'collectionPrice': x['collectionPrice'],
#      16     'trackPrice': x['trackPrice'],
#      17     'releaseDate': x['releaseDate'],
#      18     'collectionExplicitness': x['collectionExplicitness'],
#      19     'trackExplicitness': x['trackExplicitness'],
#      20     'discCount': x['discCount'],
#      21     'discNumber': x['discNumber'],
#      22     'trackCount': x['trackCount'],
#      23     'trackNumber': x['trackNumber'],
#      24     'trackTimeMillis': x['trackTimeMillis'],
#      25     'country': x['country'],
#      26     'currency': x['currency'],
#      27     'primaryGenreName': x['primaryGenreName'],
#      28     'isStreamable': x['isStreamable']
#      29 }, data)
#      30 data = list(data)
#      31 print(list(data[0].keys()))
#
# KeyError: 'collectionPrice'

# %%
def convert_millis(millis: int) -> str:
    total_seconds = millis // 1000
    seconds = total_seconds % 60
    minutes = (total_seconds // 60) % 60
    hours = (total_seconds // (60 * 60))
    return f"{hours}H{minutes}M{seconds}S"

# %%
print(set(map(lambda x: x['artistName'], data)));
Count = lambda x: x['trackName']
Count_Of_Songs = len(list(map(Count, data)))

print('Количество песен:' ,Count_Of_Songs);


print(set(list(map(lambda x: x['primaryGenreName'], data))))

Album = lambda x: x['collectionId']
Album_count = len(list(set(map(Album, data))))
print('Количество альбомов:', Album_count);

time_extractor = lambda x: x['trackTimeMillis']

Duration_of_songs = sum(list(map(time_extractor, data)))
print('Длительность всех песен:', convert_millis(Duration_of_songs))

Average_duration = Duration_of_songs / Count_Of_Songs
print('Средняя длительность песен:', convert_millis(Average_duration))

Median_time = list(map(time_extractor, data))
import statistics
print('Медиана длительности песен:', convert_millis(statistics.median(Median_time)))

longest_song = max(data, key=time_extractor)
print('Самая длинная песня:', longest_song['trackName'], ' и её длительность: ', convert_millis(longest_song['trackTimeMillis']))

shortest_song = min(data, key=time_extractor)
print('Самая короткая песня:', shortest_song['trackName'], ' и её длительность: ', convert_millis(shortest_song['trackTimeMillis']));
Song_cost = lambda x: x['trackPrice']

All_price = sum(list(map(Song_cost, data)))
print('Стоимость всех песен:', All_price, '$')

Average_price = All_price / Count_Of_Songs
print('Средняя стоимость песен:', Average_price, '$')

Median_cost = list(map(Song_cost, data))
import statistics
print('Медиана стоимости песен:', statistics.median(Median_cost), '$')

Expensive_song = max(data, key=Song_cost)
print('Самая дорогая песня:', Expensive_song['trackName'])
print( 'стоимость самой дорогой песни:',  Expensive_song['trackPrice'], '$')

Cheap_song = min(data, key=Song_cost) 
print('Самая дешёвая песня:', Cheap_song['trackName'],'Free')
print('Самая дешёвая песня:', Cheap_song['trackPrice'], '$')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 print(set(map(lambda x: x['artistName'], data)));
#       2 Count = lambda x: x['trackName']
#       3 Count_Of_Songs = len(list(map(Count, data)))
#
# NameError: name 'data' is not defined

# %%
album_count = len( list( set( map( lambda x: x['collectionName'], data ) ) ) );

for i in range(album_count):
    album_name = list( set( map( lambda x: x['collectionName'], data)))[i]
    album_data = list( filter( lambda x:album_name in x['collectionName'], data))

    
    print( 'Название альбома:', set(list( map( lambda x: x['collectionName'], album_data))))
    print( 'Количество песен:', len( list( map( lambda x: x['trackName'], album_data))))
    print( 'Самый популярный жанр:',  set(list( map( lambda x: x['primaryGenreName'], album_data))))
    print( 'Дата релиза альбома:',  list( map( lambda x: x['releaseDate'], album_data))[0])
    
    longest_song = max(data, key=time_extractor)
    print('Самая длинная песня:', longest_song['trackName'], ' и её длительность: ', convert_millis(longest_song['trackTimeMillis']))
    shortest_song = min(data, key=time_extractor)
    print('Самая короткая песня:', shortest_song['trackName'], ' и её длительность: ', convert_millis(shortest_song['trackTimeMillis']))
    
    print( 'Общая длительность песен:', convert_millis( sum( list( map( lambda x: x['trackTimeMillis'], album_data)))))
    print( 'Средняя длительность песен:', convert_millis( round( statistics.mean( list( map( lambda x : x['trackTimeMillis'], album_data))))))
    print( 'Медиана длительности песен:', convert_millis( round( statistics.median( list( map( lambda x : x['trackTimeMillis'], album_data))))))
    
    print( 'общая стоимость песен: ≈', round( sum( list( map( lambda x: x['trackPrice'], album_data ) ) ), 2 ), '$' )
    print( 'средняя стоимость песен: ≈', round( statistics.mean( list( map( lambda x: x['trackPrice'], album_data ) ) ), 2 ), '$' )
    print( 'медиана стоимости песен: ≈', round( statistics.median( list( map( lambda x: x['trackPrice'], album_data ) ) ), 2 ), '$' )
    print( 'название самой дорогой песни:', max( album_data, key = lambda x: x['trackPrice'] )['trackName'] )
    print( 'стоимость самой дорогой песни:', max( album_data, key = lambda x: x['trackPrice'] )['trackPrice'], '$' )
    print( 'название самой дешевой песни:', min( album_data, key = lambda x: x['trackPrice'] )['trackName'] )
    print( 'стоимость самой дешевой песни:', min( album_data, key = lambda x: x['trackPrice'] )['trackPrice'], '$' )
    print( '------------------------------------' )
# Out:
# Название альбома: {'Lithium - Single'}
# Количество песен: 1
# Самый популярный жанр: {'Alternative'}
# Дата релиза альбома: 1991-09-24 12:00:00+00:00
# Самая длинная песня: Gallons of Rubbing Alcohol Flow Through the Strip  и её длительность:  0H7M34S
# Самая короткая песня: Intro (Live At London Astoria, UK, December 3, 1989)  и её длительность:  0H0M52S
# Общая длительность песен: 0H4M19S
# Средняя длительность песен: 0H4M19S
# Медиана длительности песен: 0H4M19S
# общая стоимость песен: ≈ 1.29 $
# средняя стоимость песен: ≈ 1.29 $
# медиана стоимости песен: ≈ 1.29 $
# название самой дорогой песни: Lithium
# стоимость самой дорогой песни: 1.29 $
# название самой дешевой песни: Lithium
# стоимость самой дешевой песни: 1.29 $
# ------------------------------------
# Название альбома: {'Bleach'}
# Количество песен: 25
# Самый популярный жанр: {'Alternative'}
# Дата релиза альбома: 1989-06-15 07:00:00+00:00
# Самая длинная песня: Gallons of Rubbing Alcohol Flow Through the Strip  и её длительность:  0H7M34S
# Самая короткая песня: Intro (Live At London Astoria, UK, December 3, 1989)  и её длительность:  0H0M52S
# Общая длительность песен: 1H16M37S
# Средняя длительность песен: 0H3M3S
# Медиана длительности песен: 0H2M57S
# общая стоимость песен: ≈ 24.75 $
# средняя стоимость песен: ≈ 0.99 $
# медиана стоимости песен: ≈ 0.99 $
# название самой дорогой песни: About a Girl
# стоимость самой дорогой песни: 0.99 $
# название самой дешевой песни: About a Girl
# стоимость самой дешевой песни: 0.99 $
# ------------------------------------
# Название альбома: {'Live at Reading'}
# Количество песен: 3
# Самый популярный жанр: {'Alternative'}
# Дата релиза альбома: 2009-11-03 08:00:00+00:00
# Самая длинная песня: Gallons of Rubbing Alcohol Flow Through the Strip  и её длительность:  0H7M34S
# Самая короткая песня: Intro (Live At London Astoria, UK, December 3, 1989)  и её длительность:  0H0M52S
# Общая длительность песен: 0H11M48S
# Средняя длительность песен: 0H3M56S
# Медиана длительности песен: 0H4M21S
# общая стоимость песен: ≈ 3.87 $
# средняя стоимость песен: ≈ 1.29 $
# медиана стоимости песен: ≈ 1.29 $
# название самой дорогой песни: Lithium (Live at Reading, 08/30/92)
# стоимость самой дорогой песни: 1.29 $
# название самой дешевой песни: Lithium (Live at Reading, 08/30/92)
# стоимость самой дешевой песни: 1.29 $
# ------------------------------------
# Название альбома: {'Lithium (Acoustic Version) - Single'}
# Количество песен: 1
# Самый популярный жанр: {'Alternative'}
# Дата релиза альбома: 2004-11-23 12:00:00+00:00
# Самая длинная песня: Gallons of Rubbing Alcohol Flow Through the Strip  и её длительность:  0H7M34S
# Самая короткая песня: Intro (Live At London Astoria, UK, December 3, 1989)  и её длительность:  0H0M52S
# Общая длительность песен: 0H1M49S
# Средняя длительность песен: 0H1M49S
# Медиана длительности песен: 0H1M49S
# общая стоимость песен: ≈ 0.99 $
# средняя стоимость песен: ≈ 0.99 $
# медиана стоимости песен: ≈ 0.99 $
# название самой дорогой песни: Lithium (Acoustic Version)
# стоимость самой дорогой песни: 0.99 $
# название самой дешевой песни: Lithium (Acoustic Version)
# стоимость самой дешевой песни: 0.99 $
# ------------------------------------
# Название альбома: {'Nirvana'}
# Количество песен: 14
# Самый популярный жанр: {'Alternative'}
# Дата релиза альбома: 1991-09-10 12:00:00+00:00
# Самая длинная песня: Gallons of Rubbing Alcohol Flow Through the Strip  и её длительность:  0H7M34S
# Самая короткая песня: Intro (Live At London Astoria, UK, December 3, 1989)  и её длительность:  0H0M52S
# Общая длительность песен: 0H49M10S
# Средняя длительность песен: 0H3M30S
# Медиана длительности песен: 0H3M38S
# общая стоимость песен: ≈ 18.06 $
# средняя стоимость песен: ≈ 1.29 $
# медиана стоимости песен: ≈ 1.29 $
# название самой дорогой песни: Smells Like Teen Spirit
# стоимость самой дорогой песни: 1.29 $
# название самой дешевой песни: Smells Like Teen Spirit
# стоимость самой дешевой песни: 1.29 $
# ------------------------------------
# Название альбома: {'Nevermind'}
# Количество песен: 13
# Самый популярный жанр: {'Alternative'}
# Дата релиза альбома: 1991-09-10 12:00:00+00:00
# Самая длинная песня: Gallons of Rubbing Alcohol Flow Through the Strip  и её длительность:  0H7M34S
# Самая короткая песня: Intro (Live At London Astoria, UK, December 3, 1989)  и её длительность:  0H0M52S
# Общая длительность песен: 0H49M20S
# Средняя длительность песен: 0H3M47S
# Медиана длительности песен: 0H3M38S
# общая стоимость песен: ≈ 16.77 $
# средняя стоимость песен: ≈ 1.29 $
# медиана стоимости песен: ≈ 1.29 $
# название самой дорогой песни: Smells Like Teen Spirit
# стоимость самой дорогой песни: 1.29 $
# название самой дешевой песни: Smells Like Teen Spirit
# стоимость самой дешевой песни: 1.29 $
# ------------------------------------
# Название альбома: {'MTV Unplugged In New York (Live Acoustic)'}
# Количество песен: 17
# Самый популярный жанр: {'Alternative'}
# Дата релиза альбома: 1994-11-01 12:00:00+00:00
# Самая длинная песня: Gallons of Rubbing Alcohol Flow Through the Strip  и её длительность:  0H7M34S
# Самая короткая песня: Intro (Live At London Astoria, UK, December 3, 1989)  и её длительность:  0H0M52S
# Общая длительность песен: 1H5M10S
# Средняя длительность песен: 0H3M50S
# Медиана длительности песен: 0H3M40S
# общая стоимость песен: ≈ 21.93 $
# средняя стоимость песен: ≈ 1.29 $
# медиана стоимости песен: ≈ 1.29 $
# название самой дорогой песни: Lake of Fire (Live Acoustic)
# стоимость самой дорогой песни: 1.29 $
# название самой дешевой песни: Lake of Fire (Live Acoustic)
# стоимость самой дешевой песни: 1.29 $
# ------------------------------------
# Название альбома: {'In Utero (20th Anniversary Edition)'}
# Количество песен: 12
# Самый популярный жанр: {'Alternative'}
# Дата релиза альбома: 1993-09-21 12:00:00+00:00
# Самая длинная песня: Gallons of Rubbing Alcohol Flow Through the Strip  и её длительность:  0H7M34S
# Самая короткая песня: Intro (Live At London Astoria, UK, December 3, 1989)  и её длительность:  0H0M52S
# Общая длительность песен: 0H41M30S
# Средняя длительность песен: 0H3M27S
# Медиана длительности песен: 0H3M43S
# общая стоимость песен: ≈ 15.48 $
# средняя стоимость песен: ≈ 1.29 $
# медиана стоимости песен: ≈ 1.29 $
# название самой дорогой песни: All Apologies
# стоимость самой дорогой песни: 1.29 $
# название самой дешевой песни: All Apologies
# стоимость самой дешевой песни: 1.29 $
# ------------------------------------
# Название альбома: {'Incesticide'}
# Количество песен: 12
# Самый популярный жанр: {'Alternative'}
# Дата релиза альбома: 1992-12-14 12:00:00+00:00
# Самая длинная песня: Gallons of Rubbing Alcohol Flow Through the Strip  и её длительность:  0H7M34S
# Самая короткая песня: Intro (Live At London Astoria, UK, December 3, 1989)  и её длительность:  0H0M52S
# Общая длительность песен: 0H32M33S
# Средняя длительность песен: 0H2M42S
# Медиана длительности песен: 0H2M17S
# общая стоимость песен: ≈ 15.48 $
# средняя стоимость песен: ≈ 1.29 $
# медиана стоимости песен: ≈ 1.29 $
# название самой дорогой песни: Aneurysm
# стоимость самой дорогой песни: 1.29 $
# название самой дешевой песни: Aneurysm
# стоимость самой дешевой песни: 1.29 $
# ------------------------------------
# Название альбома: {'In Utero', 'In Utero (20th Anniversary Edition)'}
# Количество песен: 63
# Самый популярный жанр: {'Grunge', 'Alternative'}
# Дата релиза альбома: 1993-09-21 12:00:00+00:00
# Самая длинная песня: Gallons of Rubbing Alcohol Flow Through the Strip  и её длительность:  0H7M34S
# Самая короткая песня: Intro (Live At London Astoria, UK, December 3, 1989)  и её длительность:  0H0M52S
# Общая длительность песен: 3H45M33S
# Средняя длительность песен: 0H3M34S
# Медиана длительности песен: 0H3M38S
# общая стоимость песен: ≈ 81.27 $
# средняя стоимость песен: ≈ 1.29 $
# медиана стоимости песен: ≈ 1.29 $
# название самой дорогой песни: All Apologies
# стоимость самой дорогой песни: 1.29 $
# название самой дешевой песни: All Apologies
# стоимость самой дешевой песни: 1.29 $
# ------------------------------------
# Название альбома: {'Sliver: The Best of the Box'}
# Количество песен: 22
# Самый популярный жанр: {'Grunge'}
# Дата релиза альбома: 2005-10-31 12:00:00+00:00
# Самая длинная песня: Gallons of Rubbing Alcohol Flow Through the Strip  и её длительность:  0H7M34S
# Самая короткая песня: Intro (Live At London Astoria, UK, December 3, 1989)  и её длительность:  0H0M52S
# Общая длительность песен: 1H14M1S
# Средняя длительность песен: 0H3M21S
# Медиана длительности песен: 0H3M22S
# общая стоимость песен: ≈ 28.08 $
# средняя стоимость песен: ≈ 1.28 $
# медиана стоимости песен: ≈ 1.29 $
# название самой дорогой песни: Sappy (1990 Studio Demo)
# стоимость самой дорогой песни: 1.29 $
# название самой дешевой песни: Spank Thru (1985 Fecal Matter Demo)
# стоимость самой дешевой песни: 0.99 $
# ------------------------------------
# Название альбома: {'With the Lights Out'}
# Количество песен: 12
# Самый популярный жанр: {'Rock'}
# Дата релиза альбома: 2004-11-23 12:00:00+00:00
# Самая длинная песня: Gallons of Rubbing Alcohol Flow Through the Strip  и её длительность:  0H7M34S
# Самая короткая песня: Intro (Live At London Astoria, UK, December 3, 1989)  и её длительность:  0H0M52S
# Общая длительность песен: 0H40M13S
# Средняя длительность песен: 0H3M21S
# Медиана длительности песен: 0H3M20S
# общая стоимость песен: ≈ 15.48 $
# средняя стоимость песен: ≈ 1.29 $
# медиана стоимости песен: ≈ 1.29 $
# название самой дорогой песни: Sappy
# стоимость самой дорогой песни: 1.29 $
# название самой дешевой песни: Sappy
# стоимость самой дешевой песни: 1.29 $
# ------------------------------------
# Название альбома: {'From the Muddy Banks of the Wishkah (Live)'}
# Количество песен: 17
# Самый популярный жанр: {'Alternative'}
# Дата релиза альбома: 1996-10-01 12:00:00+00:00
# Самая длинная песня: Gallons of Rubbing Alcohol Flow Through the Strip  и её длительность:  0H7M34S
# Самая короткая песня: Intro (Live At London Astoria, UK, December 3, 1989)  и её длительность:  0H0M52S
# Общая длительность песен: 0H54M1S
# Средняя длительность песен: 0H3M10S
# Медиана длительности песен: 0H3M28S
# общая стоимость песен: ≈ 20.13 $
# средняя стоимость песен: ≈ 1.18 $
# медиана стоимости песен: ≈ 1.29 $
# название самой дорогой песни: Aneurysm (Live At Del Mar Fairgrounds, CA., December 28, 1991)
# стоимость самой дорогой песни: 1.29 $
# название самой дешевой песни: Heart-Shaped Box (Live In Los Angeles, CA, December 30, 1993)
# стоимость самой дешевой песни: 0.99 $
# ------------------------------------
